# %%
import pandas as pd

# %%
dataset = pd.read_csv('telecom-churn.csv')

# %%
dataset.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
dataset.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
print(dataset.shape)
# Out:
# (3333, 20)

# %%
print(dataset.shape[1])
# Out:
# 20

# %%
dataset.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %%
dataset.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
dataset['Churn'].value_counts()
# Out:
# Churn
# False    2850
# True      483
# Name: count, dtype: int64

# %%
dataset.groupby('Churn')[['Total day minutes', 'Total eve minutes', 'Total night minutes']].mean()
# Out:
#        Total day minutes  Total eve minutes  Total night minutes
# Churn
# False         175.175754         199.043298           200.133193
# True          206.914079         212.410145           205.231677

# %%
dataset.groupby('Churn')[['Total day charge', 'Total eve charge', 'Total night charge', 'Total intl charge']].mean()
# Out:
#        Total day charge  Total eve charge  Total night charge  \
# Churn
# False         29.780421         16.918909            9.006074
# True          35.175921         18.054969            9.235528
#
#        Total intl charge
# Churn
# False           2.743404
# True            2.889545

# %%
dataset.groupby('Churn')[['Total day calls', 'Total eve calls', 'Total night calls']].describe()
# Out:
#       Total day calls                                                         \
#                 count        mean        std  min   25%    50%    75%    max
# Churn
# False          2850.0  100.283158  19.801157  0.0  87.0  100.0  114.0  163.0
# True            483.0  101.335404  21.582307  0.0  87.5  103.0  116.5  165.0
#
#       Total eve calls              ...               Total night calls  \
#                 count        mean  ...    75%    max             count
# Churn                              ...
# False          2850.0  100.038596  ...  114.0  170.0            2850.0
# True            483.0  100.561077  ...  114.0  168.0             483.0
#
#
#              mean        std   min   25%    50%    75%    max
# Churn
# False  100.058246  19.506246  33.0  87.0  100.0  113.0  175.0
# True   100.399586  19.950659  49.0  85.0  100.0  115.0  158.0
#
# [2 rows x 24 columns]

# %%
dataset.groupby('Area code')['Churn'].sum()
# Out:
# Area code
# 408    122
# 415    236
# 510    125
# Name: Churn, dtype: int64

# %%
dataset.groupby('State')['Churn'].sum()
# Out:
# State
# AK     3
# AL     8
# AR    11
# AZ     4
# CA     9
# CO     9
# CT    12
# DC     5
# DE     9
# FL     8
# GA     8
# HI     3
# IA     3
# ID     9
# IL     5
# IN     9
# KS    13
# KY     8
# LA     4
# MA    11
# MD    17
# ME    13
# MI    16
# MN    15
# MO     7
# MS    14
# MT    14
# NC    11
# ND     6
# NE     5
# NH     9
# NJ    18
# NM     6
# NV    14
# NY    15
# OH    10
# OK     9
# OR    11
# PA     8
# RI     6
# SC    14
# SD     8
# TN     5
# TX    18
# UT    10
# VA     5
# VT     8
# WA    14
# WI     7
# WV    10
# WY     9
# Name: Churn, dtype: int64

# %%
dataset.groupby('International plan')[['Total day calls', 'Total eve calls', 'Total night calls', 'Total intl calls']].sum()
# Out:
#                     Total day calls  Total eve calls  Total night calls  \
# International plan
# No                           302237           301224             301084
# Yes                           32515            32457              32575
#
#                     Total intl calls
# International plan
# No                             13441
# Yes                             1489

# %%
dataset.groupby('International plan')[['Total day minutes', 'Total eve minutes', 'Total night minutes', 'Total intl minutes']].mean()
# Out:
#                     Total day minutes  Total eve minutes  Total night minutes  \
# International plan
# No                         178.893887         200.663090           201.350831
# Yes                        187.986997         203.936842           196.410217
#
#                     Total intl minutes
# International plan
# No                           10.195349
# Yes                          10.628173

# %%
dataset['Customer service calls'].value_counts()
# Out:
# Customer service calls
# 1    1181
# 2     759
# 0     697
# 3     429
# 4     166
# 5      66
# 6      22
# 7       9
# 9       2
# 8       2
# Name: count, dtype: int64

# %%
dataset['International plan'].value_counts()
# Out:
# International plan
# No     3010
# Yes     323
# Name: count, dtype: int64

# %%
dataset['Voice mail plan'].value_counts()
# Out:
# Voice mail plan
# No     2411
# Yes     922
# Name: count, dtype: int64

# %%
loyal_customers= dataset[dataset['Churn'] == False]
print(loyal_customers.describe())
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     2850.000000  2850.000000            2850.000000        2850.000000
# mean       100.793684   437.074737               8.604561         175.175754
# std         39.882350    42.306156              13.913125          50.181655
# min          1.000000   408.000000               0.000000           0.000000
# 25%         73.000000   408.000000               0.000000         142.825000
# 50%        100.000000   415.000000               0.000000         177.200000
# 75%        127.000000   510.000000              22.000000         210.300000
# max        243.000000   510.000000              51.000000         315.600000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      2850.000000       2850.000000        2850.000000      2850.000000
# mean        100.283158         29.780421         199.043298       100.038596
# ...
